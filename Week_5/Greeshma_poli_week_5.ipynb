# %% [markdown]
# Name: Greeshma Poli
#
# Course number: HDS 5230 - High Performance Computing
#
# Assignment number: Week 05 - Dask Programming Assignment

# %%
# Import necessary libraries:
import dask.dataframe as dd
import pandas as pd
import numpy as np

# %%
# defining data types for each column to ensure consistency and optimize memory usage
dtypes = {'name':str,'level':str,'city':object,'county':str,'state':str,'country':str,'population':np.float64,'lat':float,'long':float,'url':str,'aggregate':object,'tz':str,'cases':np.float64,'deaths':np.float64,'recovered':np.float64,'active':np.float64,'tested':np.float64,'hospitalized':np.float64,'hospitalized_current':np.float64,'discharged':np.float64,
    'icu':np.float64,'icu_current':np.float64,'growthFactor':np.float64,'date':object}

# %%
# Load dataset using Dask
df = dd.read_csv("timeseries.csv",dtype=dtypes)

# %% [markdown]
# We use Dask to load the dataset because COVID-19 data can be huge, covering many countries and dates. Instead of loading the entire file into memory like Pandas, Dask loads it in chunks (partitions) and processes them in parallel across multiple CPU cores or even multiple machines in a distributed system. This prevents memory overload and speeds up the process significantly

# %%
df.head()
# Out:
#   locationID slug     name    level  city county state  country    lat  long  \
# 0    iso1:ad   ad  Andorra  country  <NA>   <NA>  <NA>  Andorra  42.55  1.58
# 1    iso1:ad   ad  Andorra  country  <NA>   <NA>  <NA>  Andorra  42.55  1.58
# 2    iso1:ad   ad  Andorra  country  <NA>   <NA>  <NA>  Andorra  42.55  1.58
# 3    iso1:ad   ad  Andorra  country  <NA>   <NA>  <NA>  Andorra  42.55  1.58
# 4    iso1:ad   ad  Andorra  country  <NA>   <NA>  <NA>  Andorra  42.55  1.58
#
#    ...  deaths recovered active  tested  hospitalized  hospitalized_current  \
# 0  ...     0.0       0.0    NaN     NaN           NaN                   NaN
# 1  ...     0.0       0.0    NaN     NaN           NaN                   NaN
# 2  ...     0.0       0.0    NaN     NaN           NaN                   NaN
# 3  ...     0.0       0.0    NaN     NaN           NaN                   NaN
# 4  ...     0.0       0.0    NaN     NaN           NaN                   NaN
#
#    discharged  icu  icu_current        date
# 0         NaN  NaN          NaN  2020-01-22
# 1         NaN  NaN          NaN  2020-01-23
# 2         NaN  NaN          NaN  2020-01-24
# 3         NaN  NaN          NaN  2020-01-25
# 4         NaN  NaN          NaN  2020-01-26
#
# [5 rows x 24 columns]

# %%
# Filter dataset to include only rows where the country is 'United States'
df_us = df[df['country'] == 'United States']

# %%
# print results
df_us.head()
# Out:
#        locationID slug           name    level  city county state  \
# 239811    iso1:us   us  United States  country  <NA>   <NA>  <NA>
# 239812    iso1:us   us  United States  country  <NA>   <NA>  <NA>
# 239813    iso1:us   us  United States  country  <NA>   <NA>  <NA>
# 239814    iso1:us   us  United States  country  <NA>   <NA>  <NA>
# 239815    iso1:us   us  United States  country  <NA>   <NA>  <NA>
#
#               country    lat    long  ...  deaths recovered active  tested  \
# 239811  United States  45.67 -112.87  ...     NaN       NaN    NaN     NaN
# 239812  United States  45.67 -112.87  ...     NaN       NaN    NaN     NaN
# 239813  United States  45.67 -112.87  ...     NaN       NaN    NaN     NaN
# 239814  United States  45.67 -112.87  ...     NaN       NaN    NaN     NaN
# 239815  United States  45.67 -112.87  ...     NaN       NaN    NaN     NaN
#
#         hospitalized  hospitalized_current  discharged  icu  icu_current  \
# 239811           NaN                   NaN         NaN  NaN          NaN
# 239812           NaN                   NaN         NaN  NaN          NaN
# 239813           NaN                   NaN         NaN  NaN          NaN
# 239814           NaN                   NaN         NaN  NaN          NaN
# 239815           NaN                   NaN         NaN  NaN          NaN
#
#               date
# 239811  2020-01-22
# 239812  2020-01-23
# 239813  2020-01-24
# 239814  2020-01-25
# 239815  2020-01-26
#
# [5 rows x 24 columns]

# %% [markdown]
# Extracting records specific to the United States is a basic operation, but when handling millions of rows, it can be slow in Pandas. Dask optimizes this by applying filters independently to each partition, making the process significantly faster. In a distributed setup, filtering could be further accelerated by processing different partitions across machines.

# %%
# Convert date column to datetime format
df_us['date'] = dd.to_datetime(df_us['date'])

# %% [markdown]
# Dates are crucial for COVID-19 trend analysis, but converting them from text to a proper datetime format can be slow. Dask converts dates in parallel across partitions, so instead of processing millions of rows sequentially (as Pandas does), the work is split across multiple CPU cores, speeding up the operation.

# %%
# Filter for the time period (2020-Jan-01 to 2021-Feb-28)
df_us = df_us[(df_us['date'] >= '2020-01-01') & (df_us['date'] <= '2021-02-28')]

# %% [markdown]
# Filtering for Time Range (2020-Jan-01 to 2021-Feb-28): Like the previous filtering task, a date range filter is something that Dask can easily parallelize. It gets you the work done faster with large datasets by doing different chunks of data at the same time. With small datasets, you may not notice a significant difference, but Dask still makes it scalable in case your dataset grows.

# %%
# Group by state and compute total deaths and average population
state_wise_mortality = df_us.groupby('state').agg({'deaths': 'sum', 'population': 'mean'}).compute()

# %% [markdown]
# Aggregating total COVID-19 deaths and average population per state is computationally intensive. Dask distributes this workload across partitions and, if needed, across multiple machines, ensuring faster processing. This is particularly useful for large-scale data analysis.

# %%
# print results
print(state_wise_mortality)
# Out:
#                              deaths    population
# state
# Alaska                       7965.0  4.876967e+04
# Alabama                    438471.0  1.442113e+05
# Arkansas                   158952.0  9.616907e+04
# American Samoa                  0.0  5.568900e+04
# Arizona                    939211.0  9.098396e+05
# California                2783684.0  1.339739e+06
# Colorado                   546938.0  1.771919e+05
# Connecticut               1383249.0  7.922860e+05
# Washington, D.C.           175246.0  7.057490e+05
# Delaware                   120278.0  4.868820e+05
# Florida                   2161963.0  6.316981e+05
# Georgia                   1230519.0  1.550214e+05
# Guam                         1890.0  1.677720e+05
# Hawaii                      14242.0  4.719573e+05
# Iowa                       264347.0  7.384984e+04
# Idaho                       66368.0  7.942511e+04
# Illinois                  2238987.0  2.879959e+05
# Indiana                    283501.0  1.447789e+05
# Kansas                     114847.0  5.496819e+04
# Kentucky                   237486.0  7.384583e+04
# Louisiana                 1217102.0  1.430398e+05
# Massachusetts             2617844.0  1.039983e+06
# Maryland                  1024777.0  4.836544e+05
# Maine                       36740.0  1.744745e+05
# Michigan                  2107456.0  2.377823e+05
# Minnesota                  470852.0  1.281735e+05
# Missouri                   320423.0  1.056162e+05
# Northern Mariana Islands      370.0  5.514400e+04
# Mississippi                504736.0  7.171443e+04
# Montana                     20877.0  3.750098e+04
# North Carolina             595936.0  2.076848e+05
# North Dakota                34648.0  3.283063e+04
# Nebraska                    95850.0  4.115762e+04
# New Hampshire              112790.0  2.476136e+05
# New Jersey                4609656.0  8.074718e+05
# New Mexico                 182077.0  1.233429e+05
# Nevada                     270529.0  3.422396e+05
# New York                  9781636.0  6.175734e+05
# Ohio                      1029731.0  2.626764e+05
# Oklahoma                   184060.0  1.014608e+05
# Oregon                     100177.0  2.279858e+05
# Pennsylvania              2145790.0  3.765291e+05
# Puerto Rico                 45430.0  3.411307e+06

# %%
# Compute per-capita mortality
#This step calculates the total COVID-19 deaths per state, adjusted by the average population, to measure mortality risk.
state_wise_mortality['per_capita_mortality'] = state_wise_mortality['deaths'] / state_wise_mortality['population']

# %% [markdown]
# Per-capita mortality (deaths/population) is a straightforward calculation, but applying it to large datasets benefits from parallel execution across partitions. Instead of computing it sequentially, Dask runs these calculations in parallel, reducing processing time.

# %%
# Rank states by per-capita mortality
state_wise_mortality_ranked = state_wise_mortality.sort_values(by='per_capita_mortality', ascending=False)

# %% [markdown]
# Sorting is one of the most expensive operations in data processing. Since sorting requires comparing many values, Dask speeds this up by sorting each partition separately in parallel before merging the results. This is much faster than Pandas, which would sort everything sequentially.

# %%
# print results
print(state_wise_mortality_ranked)
# Out:
#                              deaths    population  per_capita_mortality
# state
# New York                  9781636.0  6.175734e+05             15.838824
# Michigan                  2107456.0  2.377823e+05              8.862964
# Louisiana                 1217102.0  1.430398e+05              8.508834
# Georgia                   1230519.0  1.550214e+05              7.937739
# Illinois                  2238987.0  2.879959e+05              7.774370
# Mississippi                504736.0  7.171443e+04              7.038137
# New Jersey                4609656.0  8.074718e+05              5.708752
# Pennsylvania              2145790.0  3.765291e+05              5.698869
# Ohio                      1029731.0  2.626764e+05              3.920150
# Minnesota                  470852.0  1.281735e+05              3.673553
# Iowa                       264347.0  7.384984e+04              3.579520
# Florida                   2161963.0  6.316981e+05              3.422462
# Kentucky                   237486.0  7.384583e+04              3.215970
# Colorado                   546938.0  1.771919e+05              3.086699
# Alabama                    438471.0  1.442113e+05              3.040476
# Missouri                   320423.0  1.056162e+05              3.033844
# North Carolina             595936.0  2.076848e+05              2.869425
# Massachusetts             2617844.0  1.039983e+06              2.517199
# Nebraska                    95850.0  4.115762e+04              2.328852
# Maryland                  1024777.0  4.836544e+05              2.118821
# Kansas                     114847.0  5.496819e+04              2.089336
# California                2783684.0  1.339739e+06              2.077781
# Indiana                    283501.0  1.447789e+05              1.958165
# Oklahoma                   184060.0  1.014608e+05              1.814100
# Connecticut               1383249.0  7.922860e+05              1.745896
# Arkansas                   158952.0  9.616907e+04              1.652839
# New Mexico                 182077.0  1.233429e+05              1.476186
# North Dakota                34648.0  3.283063e+04              1.055356
# Arizona                    939211.0  9.098396e+05              1.032282
# Idaho                       66368.0  7.942511e+04              0.835605
# Nevada                     270529.0  3.422396e+05              0.790467
# Montana                     20877.0  3.750098e+04              0.556705
# New Hampshire              112790.0  2.476136e+05              0.455508
# Oregon                     100177.0  2.279858e+05              0.439400
# Washington, D.C.           175246.0  7.057490e+05              0.248312
# Delaware                   120278.0  4.868820e+05              0.247037
# Maine                       36740.0  1.744745e+05              0.210575
# Alaska                       7965.0  4.876967e+04              0.163319
# Hawaii                      14242.0  4.719573e+05              0.030176
# Puerto Rico                 45430.0  3.411307e+06              0.013317
# Guam                         1890.0  1.677720e+05              0.011265
# Northern Mariana Islands      370.0  5.514400e+04              0.006710
# American Samoa                  0.0  5.568900e+04              0.000000

# %%
# Compute CFR per month
df_us['month'] = df_us['date'].dt.to_period('M')
cfr_per_month = df_us.groupby(['state', 'month']).agg({'deaths': 'sum', 'cases': 'sum'}).compute()
cfr_per_month['CFR'] = cfr_per_month['deaths'] / cfr_per_month['cases']

# %%
# print results
print(cfr_per_month)
# Out:
#                       deaths      cases       CFR
# state       month
# Alaska      2020-01      0.0        0.0       NaN
#             2020-02      0.0        0.0       NaN
#             2020-03     21.0     1566.0  0.013410
#             2020-04    404.0    16558.0  0.024399
#             2020-05    610.0    24501.0  0.024897
# ...                      ...        ...       ...
# Puerto Rico 2020-06   4380.0   255489.0  0.017144
#             2020-07   5485.0   519733.0  0.010553
#             2020-08  10262.0  1173434.0  0.008745
#             2020-09  16703.0  1720918.0  0.009706
#             2020-10   3400.0   363492.0  0.009354
#
# [430 rows x 3 columns]

# %% [markdown]
# COVID-19 fatality rates fluctuate over time, so we group data by state and month. Since grouping is computationally expensive, Dask distributes this operation across partitions and, if needed, across multiple machines, making it highly efficient for large datasets

# %%
# Pivot table for CFR (50 states X 14 months)
cfr_matrix = cfr_per_month.pivot_table(values='CFR', index='state', columns='month')

# %%
# print results
print(cfr_matrix)
# Out:
# month                     2020-01   2020-02   2020-03   2020-04   2020-05  \
# state
# Alabama                       NaN       NaN  0.006703  0.032222  0.038915
# Alaska                        NaN       NaN  0.013410  0.024399  0.024897
# Arizona                       0.0  0.000000  0.014445  0.037281  0.047639
# Arkansas                      NaN       NaN  0.009310  0.019205  0.021140
# California                    0.0  0.056836  0.021733  0.035652  0.040133
# Colorado                      NaN       NaN  0.017962  0.044440  0.050536
# Connecticut                   NaN       NaN  0.019335  0.064518  0.090128
# Delaware                      NaN       NaN  0.023356  0.032791  0.043008
# Florida                       NaN       NaN  0.014030  0.029117  0.043550
# Georgia                       NaN       NaN  0.030493  0.039662  0.044299
# Guam                          NaN       NaN  0.021318  0.036316  0.031658
# Hawaii                        NaN       NaN  0.001512  0.018048  0.026852
# Idaho                         NaN       NaN  0.013869  0.023752  0.030246
# Illinois                      0.0  0.000000  0.013102  0.040660  0.044307
# Indiana                       NaN       NaN  0.027359  0.052470  0.061073
# Iowa                          NaN       NaN  0.009380  0.023362  0.024393
# Kansas                        NaN       NaN  0.024211  0.039960  0.023175
# Kentucky                      NaN       NaN  0.026768  0.052092  0.046224
# Louisiana                     NaN       NaN  0.039492  0.051872  0.069136
# Maine                         NaN       NaN  0.006216  0.037826  0.041816
# Maryland                      NaN       NaN  0.014140  0.043046  0.049936
# Massachusetts                 0.0  0.000000  0.009992  0.043952  0.065263
# Michigan                      NaN       NaN  0.016704  0.075860  0.093363
# Minnesota                     NaN       NaN  0.007350  0.048197  0.042661
# Mississippi                   NaN       NaN  0.014943  0.036224  0.045930
# Missouri                      NaN       NaN  0.015801  0.037548  0.058404
# Montana                       NaN       NaN  0.010531  0.024316  0.034431
# Nebraska                      NaN  0.000000  0.007666  0.019765  0.012483
# Nevada                        NaN       NaN  0.028250  0.043998  0.051645
# New Hampshire                 NaN       NaN  0.007689  0.027114  0.046517
# New Jersey                    NaN       NaN  0.016461  0.053562  0.074834
# New Mexico                    NaN       NaN  0.007499  0.029398  0.043316
# New York                      NaN       NaN  0.017368  0.057165  0.070581
# North Carolina                NaN       NaN  0.003588  0.028041  0.034749
# North Dakota                  NaN       NaN  0.010437  0.019868  0.020116
# Northern Mariana Islands      NaN       NaN  0.000000  0.152542  0.105263
# Ohio                          NaN       NaN  0.018007  0.043601  0.058658
# Oklahoma                      NaN       NaN  0.032883  0.054406  0.055306
# Oregon                        NaN  0.000000  0.027760  0.036076  0.038386
# Pennsylvania                  NaN       NaN  0.011112  0.035163  0.068200
# Puerto Rico                   NaN       NaN  0.035642  0.054702  0.031666
# Washington, D.C.              NaN       NaN  0.014823  0.037814  0.052552
#
# month                      2020-06   2020-07   2020-08   2020-09   2020-10
# state
# Alabama                   0.029667  0.019949  0.017632  0.017316  0.016174
# Alaska                    0.016538  0.009262  0.006377  0.006865  0.006989
# Arizona                   0.028961  0.019429  0.023180  0.025531  0.025865
# Arkansas                  0.014667  0.011141  0.011671  0.015120  0.016536
# California                0.031962  0.020723  0.018370  0.018988  0.019374
# Colorado                  0.050317  0.043975  0.035856  0.031685  0.028444
# Connecticut               0.093261  0.093149  0.088977  0.084642  0.080728
# Delaware                  0.044746  0.039411  0.035973  0.034038  0.034099
# Florida                   0.034520  0.015409  0.016467  0.019203  0.020393
# Georgia                   0.041995  0.024676  0.020516  0.021949  0.022488
# Guam                      0.024578  0.015763  0.009195  0.014140  0.019286
# Hawaii                    0.023025  0.016419  0.007991  0.009686  0.009743
# Idaho                     0.022791  0.009226  0.009993  0.011590  0.011055
# Illinois                  0.048016  0.045585  0.037518  0.031455  0.029210
# Indiana                   0.053144  0.053144  0.053144  0.053144  0.053144
# Iowa                      0.026831  0.021048  0.018644  0.016163  0.015006
# Kansas                    0.021147  0.014504  0.011725  0.010975  0.011327
# Kentucky                  0.039906  0.030167  0.021734  0.018378  0.017069
# Louisiana                 0.061312  0.039322  0.031430  0.031863  0.032019
# Maine                     0.035822  0.031643  0.030374  0.027689  0.025757
# Maryland                  0.047196  0.043612  0.036447  0.032829  0.031177
# Massachusetts             0.072651  0.075079  0.072841  0.074920  0.073796
# Michigan                  0.090653  0.080947  0.065917  0.056284  0.051387
# Minnesota                 0.041924  0.034541  0.026651  0.022507  0.020440
# Mississippi               0.044558  0.032141  0.029042  0.030219  0.030154
# Missouri                  0.055674  0.033529  0.017712  0.014772  0.014776
# Montana                   0.029360  0.015707  0.014492  0.014585  0.012965
# Nebraska                  0.013426  0.013469  0.012016  0.011086  0.010535
# Nevada                    0.038856  0.019575  0.017785  0.019849  0.019805
# New Hampshire             0.059774  0.064117  0.060908  0.056140  0.051697
# New Jersey                0.081893  0.083894  0.080041  0.073434  0.069224
# New Mexico                0.044460  0.035987  0.031553  0.031397  0.030113
# New York                  0.073788  0.070889  0.068173  0.071332  0.071497
# North Carolina            0.024779  0.017068  0.016165  0.016590  0.016693
# North Dakota              0.022767  0.018611  0.014081  0.011069  0.011600
# Northern Mariana Islands  0.069686  0.056725  0.039340  0.031646  0.027248
# Ohio                      0.060261  0.044082  0.035525  0.032196  0.031057
# Oklahoma                  0.039081  0.019085  0.013914  0.012664  0.011572
# Oregon                    0.029844  0.018953  0.017049  0.017180  0.016496
# Pennsylvania              0.076421  0.068754  0.059023  0.052399  0.048983
# Puerto Rico               0.017144  0.010553  0.008745  0.009706  0.009354
# Washington, D.C.          0.052907  0.051239  0.045274  0.041952  0.040714

# %% [markdown]
# Pivoting data to display CFR trends requires reshaping the dataset, which can be memory-intensive. Dask performs this operation in parallel across multiple partitions, ensuring that memory usage remains optimized. If a cluster is used, Dask can distribute the task across machines, preventing slowdowns due to memory constraints.

# %%
# Compute month-to-month CFR change
mtm_cfr = cfr_matrix.diff(axis=1)

# %% [markdown]
# To analyze how CFR changed over time, we compute differences between consecutive months. Since each state's CFR values are independent of others, Dask can compute these differences in parallel across partitions, making it significantly faster than Pandas.

# %%
# Aggregate month-to-month changes per state
cfr_change_ranking = mtm_cfr.sum(axis=1).sort_values(ascending=False)

# %% [markdown]
# We sum the absolute CFR changes over time to see which states had the most fluctuations. Dask parallelizes this summation across partitions, speeding up the process. If the dataset is very large, Dask can distribute this workload across multiple machines, making it scalable.

# %%
# Output results
print("Per-capita mortality ranking:")
print(state_wise_mortality_ranked)
# Out:
# Per-capita mortality ranking:
#                              deaths    population  per_capita_mortality
# state
# New York                  9781636.0  6.175734e+05             15.838824
# Michigan                  2107456.0  2.377823e+05              8.862964
# Louisiana                 1217102.0  1.430398e+05              8.508834
# Georgia                   1230519.0  1.550214e+05              7.937739
# Illinois                  2238987.0  2.879959e+05              7.774370
# Mississippi                504736.0  7.171443e+04              7.038137
# New Jersey                4609656.0  8.074718e+05              5.708752
# Pennsylvania              2145790.0  3.765291e+05              5.698869
# Ohio                      1029731.0  2.626764e+05              3.920150
# Minnesota                  470852.0  1.281735e+05              3.673553
# Iowa                       264347.0  7.384984e+04              3.579520
# Florida                   2161963.0  6.316981e+05              3.422462
# Kentucky                   237486.0  7.384583e+04              3.215970
# Colorado                   546938.0  1.771919e+05              3.086699
# Alabama                    438471.0  1.442113e+05              3.040476
# Missouri                   320423.0  1.056162e+05              3.033844
# North Carolina             595936.0  2.076848e+05              2.869425
# Massachusetts             2617844.0  1.039983e+06              2.517199
# Nebraska                    95850.0  4.115762e+04              2.328852
# Maryland                  1024777.0  4.836544e+05              2.118821
# Kansas                     114847.0  5.496819e+04              2.089336
# California                2783684.0  1.339739e+06              2.077781
# Indiana                    283501.0  1.447789e+05              1.958165
# Oklahoma                   184060.0  1.014608e+05              1.814100
# Connecticut               1383249.0  7.922860e+05              1.745896
# Arkansas                   158952.0  9.616907e+04              1.652839
# New Mexico                 182077.0  1.233429e+05              1.476186
# North Dakota                34648.0  3.283063e+04              1.055356
# Arizona                    939211.0  9.098396e+05              1.032282
# Idaho                       66368.0  7.942511e+04              0.835605
# Nevada                     270529.0  3.422396e+05              0.790467
# Montana                     20877.0  3.750098e+04              0.556705
# New Hampshire              112790.0  2.476136e+05              0.455508
# Oregon                     100177.0  2.279858e+05              0.439400
# Washington, D.C.           175246.0  7.057490e+05              0.248312
# Delaware                   120278.0  4.868820e+05              0.247037
# Maine                       36740.0  1.744745e+05              0.210575
# Alaska                       7965.0  4.876967e+04              0.163319
# Hawaii                      14242.0  4.719573e+05              0.030176
# Puerto Rico                 45430.0  3.411307e+06              0.013317
# Guam                         1890.0  1.677720e+05              0.011265
# Northern Mariana Islands      370.0  5.514400e+04              0.006710
# American Samoa                  0.0  5.568900e+04              0.000000

# %%
print("\nCFR change ranking:")
print(cfr_change_ranking)
# Out:
# CFR change ranking:
# state
# Massachusetts               0.073796
# Connecticut                 0.061393
# New York                    0.054129
# New Jersey                  0.052762
# New Hampshire               0.044008
# Pennsylvania                0.037870
# Michigan                    0.034683
# Illinois                    0.029210
# Northern Mariana Islands    0.027248
# Washington, D.C.            0.025891
# Arizona                     0.025865
# Indiana                     0.025784
# New Mexico                  0.022614
# Maine                       0.019541
# California                  0.019374
# Maryland                    0.017037
# Oregon                      0.016496
# Mississippi                 0.015210
# North Carolina              0.013105
# Minnesota                   0.013090
# Ohio                        0.013050
# Delaware                    0.010743
# Nebraska                    0.010535
# Colorado                    0.010482
# Alabama                     0.009471
# Hawaii                      0.008231
# Arkansas                    0.007226
# Florida                     0.006363
# Iowa                        0.005627
# Montana                     0.002434
# North Dakota                0.001163
# Missouri                   -0.001026
# Guam                       -0.002032
# Idaho                      -0.002814
# Alaska                     -0.006421
# Louisiana                  -0.007473
# Georgia                    -0.008005
# Nevada                     -0.008445
# Kentucky                   -0.009699
# Kansas                     -0.012883
# Oklahoma                   -0.021311
# Puerto Rico                -0.026288
# dtype: float64

# %% [markdown]
# I feel from the COVID-19 dataset is large and growing, so traditional Pandas methods would be slow and memory-intensive. Dask enables parallelized processing, which splits work across CPU cores, and distributed processing, which spreads computations across multiple machines if necessary. This makes operations like filtering, grouping, sorting, and aggregations much faster and more scalable.
#
# For small datasets, Pandas might be sufficient, but as data size increases, Dask’s ability to process in parallel and distribute workloads makes it a powerful tool for COVID-19 analysis.
